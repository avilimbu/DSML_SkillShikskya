# %%
a = 5

# %%
data = {
    "name": "ram"
}

# %%
print(data)
# Out:
# {'name': 'ram'}

# %%
type(a)
# Out:
# int

# %%
a= 10

# %%
a
# Out:
# 10

# %%
due = 2+3j

# %%
due
# Out:
# (2+3j)

# %%
type(due)
# Out:
# complex

# %%
age= 22.3
#type conversion
age =int(age)

# %%
age
# Out:
# 22

# %%
income = 200
new_income =float(income)
new_income
# Out:
# 200.0

# %%
type(new_income)
# Out:
# float

# %%
new_income = str(new_income)

# %%
type(new_income)
# Out:
# str

# %%
17//5
#removes the decimal (floor division)
# Out:
# 3

# %%
#comparision operator

a=3
b=4
a==b
# Out:
# False

# %%
type(a==b)
# Out:
# bool

# %%
import math

# %%
math.floor(44.6)
# Out:
# 44

# %%
math.ceil(44.2)
# Out:
# 45

# %%
c= 56
d=88
result = min(c,d)

# %%
result
# Out:
# 56

# %%
round(456.5645334,2)
# Out:
# 456.56

# %%
#string

animal_name = "ferry"
type(animal_name)
# Out:
# str

# %%
animal_name[0]
# Out:
# 'f'

# %%
animal_name[-1]
# Out:
# 'y'

# %%
who = 'he is a "boy"'
who
# Out:
# 'he is a "boy"'

# %%
h = 'hfeuh'
h
# Out:
# 'hfeuh'

# %%
name ="name avhi"

# %%
who +""+ name #string concatination
# Out:
# 'he is a "boy"name avhi'

# %%
name*3 #string repetation
# Out:
# 'name avhiname avhiname avhi'

# %%
data_="python" #string slicing
data_[0:3]
# Out:
# 'pyt'

# %%
data_new = "helto, i am a very busy guy"
data_new[2:22:2]
#[start:end:step]
# Out:
# 'lo  mavr u'

# %%
data_[:-4]
# Out:
# 'py'

# %%
#string reverse
data_[::-1]
# Out:
# 'nohtyp'

# %%
#lenght function
len(data_)
# Out:
# 6

# %%
data_.upper() #changes string into upper case
# Out:
# 'PYTHON'

# %%
pit = "TRYING good Things"
pit.lower() #chnages into lower case
# Out:
# 'trying good things'

# %%
pit.title() #for each word starting characcter becomes uppercase and remaining becomes lowercase
# Out:
# 'Trying Good Things'

# %%
goes = " he goes in a tu" #removes exta space before and after string
goes.strip()
# Out:
# 'he goes in a tu'

# %%
he= "##hd#hd##"
he.strip("#")
# Out:
# 'hd#hd'

# %%
#replace
text = "I like java"
text.replace("I","You")
# Out:
# 'You like java'

# %%
#split
text = "apple, mango, banana"
type(text)
# Out:
# str

# %%
text.split() #splits a string into a list
type(text.split())
# Out:
# list

# %%
#join
word =["P","y","t","h","o","n"]
type(word)
# Out:
# list

# %%
print("".join(word))
# Out:
# Python

# %%
type("".join(word))
# Out:
# str
