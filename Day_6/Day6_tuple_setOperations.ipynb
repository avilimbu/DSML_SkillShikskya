# %%
#tuple
num = (1,2,3,4,5)
print(f"type of {num}= type(num)")
# Out:
# type of (1, 2, 3, 4, 5)= type(num)

# %%
data =[23,34,53,5,3]

# %%
#type changed from list to tuple and vice versa
data1 =tuple(data)
num1= list[num]
print(f"data1 type ={type(data1)}")
print(f"num1 type ={type(num1)}")
# Out:
# data1 type =<class 'tuple'>
# num1 type =<class 'types.GenericAlias'>

# %%
print(f"max value in data1 = {max(data1)}")
print(f"min value in data1 = {min(data1)}")
# Out:
# max value in data1 = 53
# min value in data1 = 3

# %%
print(f"length of a data 1 , {data1}= {len(data1)}")
# Out:
# length of a data 1 , (23, 34, 53, 5, 3)= 5

# %% [markdown]
#  ### **Tuples packing and unpacking**
#
# Tuple packing is when multiple values are assigned to a single variable, and Python automatically groups these values into a tuple. For example, data_pack = 1, 2, 'three' creates a tuple (1, 2, 'three'). Tuple unpacking is the reverse: it allows you to assign the elements of a tuple to multiple variables in a single statement, like a, b, c = data_pack. The number of variables on the left side of the assignment must match the number of elements in the tuple.

# %%
#tuples packing in python
data_pack = 1,2, "three"
data_pack
print(f"data_pack = {data_pack}")
# Out:
# data_pack = (1, 2, 'three')

# %%
#tuples unpacking in python
a,b,c = data_pack
print(f"a = {a}")
print(f"b = {b}")
print(f"c = {c}")
# Out:
# a = 1
# b = 2
# c = three

# %%
#wants only two value
a,b,_ = data_pack
print(f"a = {a}")
print(f"b = {b}")
# Out:
# a = 1
# b = 2

# %%
#skippin the second value
a,_,c = data_pack
print(f"a = {a}")
print(f"c = {c}")
# Out:
# a = 1
# c = three

# %%
#indexing
t =(0,5,4,6,21)
print(f"t[0] = {t[0]}")
print(f"t[1] = {t[1]}")
# Out:
# t[0] = 0
# t[1] = 5

# %%
#slicing
print(f"t[0:3] = {t[0:3]}")
print(f"t[1:3] = {t[1:3]}")
# Out:
# t[0:3] = (0, 5, 4)
# t[1:3] = (5, 4)

# %%
#concatination
t1 = (1,2,3)
t2 = (4,5,6)
t3 = t1+t2
print(f"t3 = {t3}")
# Out:
# t3 = (1, 2, 3, 4, 5, 6)

# %%
#repetation
print(f"repetation of t1*3 = {t1*3}")
# Out:
# repetation of t1*3 = (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#membership in tuple
print(f"20 exists in t1 = {20 in t1}")
print(f"20 don't exists in t2 = {20 not in t2}")
# Out:
# 20 exists in t1 = False
# 20 don't exists in t2 = True

# %%
#comparision operator
print(f"t1 == t2 = {t1 == t2}")
print(f"t1 != t2 = {t1 != t2}")
print(f"t1 > t2 = {t1 > t2}")
# Out:
# t1 == t2 = False
# t1 != t2 = True
# t1 > t2 = False

# %%
#count
print(f"total element in t1 = {t1.count(1)}")
# Out:
# total element in t1 = 1

# %% [markdown]
# # Set in Python

# %%
#Set in python
data_set = {1,2,8,4,6,3,4,6}
print(f"data_set = {data_set}")
# Out:
# data_set = {1, 2, 3, 4, 6, 8}

# %%
#set operations

# %%
#union
u1= {1,2,3,4,5}
u2= {4,5,6,7,8}
print(f"union of u1 and u2 = {u1.union(u2)}")
# Out:
# union of u1 and u2 = {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#intersection
print(f"intersection of u1 and u2 = {u1.intersection(u2)}")
# Out:
# intersection of u1 and u2 = {4, 5}

# %%
#difference
print(f"difference of u1 and u2 = {u1.difference(u2)}")
# Out:
# difference of u1 and u2 = {1, 2, 3}

# %%
#symmetric difference
print(f"symmetric difference of u1 and u2 = {u1.symmetric_difference(u2)}")
# Out:
# symmetric difference of u1 and u2 = {1, 2, 3, 6, 7, 8}

# %%
t1 = {1,2,3,4,5}
t2 = {4,5,6,7,8}
print("t1-t2 = ",t1-t2)
# Out:
# t1-t2 =  {1, 2, 3}

# %%
print("t1&t2 = ",t1&t2)
print("t1|t2 = ",t1|t2)
print("t1^t2 = ",t1^t2)
# Out:
# t1&t2 =  {4, 5}
# t1|t2 =  {1, 2, 3, 4, 5, 6, 7, 8}
# t1^t2 =  {1, 2, 3, 6, 7, 8}

# %%
t3= {4,5}
#subset
print("t3 is subset of t1 = ",t3.issubset(t1))
#superset
print("t1 is superset of t3 = ",t1.issuperset(t3))
# Out:
# t3 is subset of t1 =  True
# t1 is superset of t3 =  True

# %%
sub= t3<=t2 #finding subset

# %%
print("Is t3 is subset of t2,",sub)
# Out:
# Is t3 is subset of t2, True
